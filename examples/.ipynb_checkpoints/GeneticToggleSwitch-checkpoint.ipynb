# %%
import os
import numpy

# %%
import gillespy
class ToggleSwitch(gillespy.Model):
    """ Gardner et al. Nature (1999)
    'Construction of a genetic toggle switch in Escherichia coli'
    """
    def __init__(self, parameter_values=None):
        # Initialize the model.
        gillespy.Model.__init__(self, name="toggle_switch")
        # Parameters
        alpha1 = gillespy.Parameter(name='alpha1', expression=1)
        alpha2 = gillespy.Parameter(name='alpha2', expression=1)
        beta = gillespy.Parameter(name='beta', expression="2.0")
        gamma = gillespy.Parameter(name='gamma', expression="2.0")
        mu = gillespy.Parameter(name='mu', expression=1.0)
        self.add_parameter([alpha1, alpha2, beta, gamma, mu])

        # Species
        U = gillespy.Species(name='U', initial_value=10)
        V = gillespy.Species(name='V', initial_value=10)
        self.add_species([U, V])

        # Reactions
        cu = gillespy.Reaction(name="r1",reactants={}, products={U:1},
                propensity_function="alpha1/(1+pow(V,beta))")
        cv = gillespy.Reaction(name="r2",reactants={}, products={V:1},
                propensity_function="alpha2/(1+pow(U,gamma))")
        du = gillespy.Reaction(name="r3",reactants={U:1}, products={},
                rate=mu)
        dv = gillespy.Reaction(name="r4",reactants={V:1}, products={},
                rate=mu)
        self.add_reaction([cu,cv,du,dv])
        self.timespan(numpy.linspace(0,100,101))

# %%
model = ToggleSwitch()

# %%
results = model.run(show_labels=False)
# Out:
# ---------------------------------------------------------------------------
# SimulationError                           Traceback (most recent call last)
# <ipython-input-18-ff59d3c61a07> in <module>()
# ----> 1 results = model.run(show_labels=False)
#
# /home/abel/Documents/Code/Python/gillespy/gillespy/gillespy.pyc in run(self, number_of_trajectories, seed, solver, stochkit_home, debug, show_labels)
#     408                     number_of_trajectories=number_of_trajectories,
#     409                     stochkit_home=stochkit_home, debug=debug,
# --> 410                     show_labels=show_labels)
#     411
#     412
#
# /home/abel/Documents/Code/Python/gillespy/gillespy/gillespy.pyc in run(cls, model, t, number_of_trajectories, increment, seed, stochkit_home, algorithm, job_id, method, debug, show_labels)
#    1344                                   algorithm,
#    1345                                   job_id, extra_args=args, debug=debug,
# -> 1346                                   show_labels=show_labels)
#    1347
#    1348
#
# /home/abel/Documents/Code/Python/gillespy/gillespy/gillespy.pyc in run(self, model, t, number_of_trajectories, increment, seed, stochkit_home, algorithm, job_id, extra_args, debug, show_labels)
#    1171             raise SimulationError("stochkit executable '{0}' not found. \
#    1172                 Make sure it is your path, or set STOCHKIT_HOME envronment \
# -> 1173                 variable'".format(algorithm))
#    1174
#    1175
#
# SimulationError: stochkit executable 'ssa' not found.                 Make sure it is your path, or set STOCHKIT_HOME envronment                 variable'

# %%
# If you have the deterministic solver
dresults = model.run(solver=gillespy.StochKitODESolver, stochkit_home="/Applications/StochSS-1.6/StochSSserver.app/Contents/Resources/ode/")

# %%
plt.plot(results[0][:,0],results[0][:,1],'-r', label='U')
plt.plot(results[0][:,0],results[0][:,2],'-b', label='V')
plt.plot([0],[11])
plt.legend(loc='best')

# %%
plt.plot(dresults[0][:,0],dresults[0][:,1],'-r', label='U')
plt.plot(dresults[0][:,0],dresults[0][:,2],'-b', label='V')
plt.plot([0],[11])
plt.legend(loc='best')
